# %%
import pandas as pd

# %%
df = pd.read_csv('data/amazon_prime_titles.csv')

# %%
df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
df.shape
# Out:
# (9668, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7586 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %%
df.head(10)
# Out:
#   show_id   type                  title                     director  \
# 0      s1  Movie    The Grand Seduction                 Don McKellar
# 1      s2  Movie   Take Care Good Night                 Girish Joshi
# 2      s3  Movie   Secrets of Deception                  Josh Webber
# 3      s4  Movie     Pink: Staying True               Sonia Anderson
# 4      s5  Movie          Monster Maker                 Giles Foster
# 5      s6  Movie  Living With Dinosaurs                 Paul Weiland
# 6      s7  Movie              Hired Gun                  Fran Strine
# 7      s8  Movie           Grease Live!  Thomas Kail, Alex Rudzinski
# 8      s9  Movie        Global Meltdown                Daniel Gilboy
# 9     s10  Movie         David's Mother        Robert Allan Ackerman
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
filt = df['country'] == 'India'
df[filt].head(50)
# Out:
#      show_id     type                                    title  \
# 1         s2    Movie                     Take Care Good Night
# 107     s108    Movie                                   Whoop!
# 142     s143    Movie                      Wedding Cha Shinema
# 178     s179    Movie                                 Viswasam
# 180     s181    Movie                                    Virus
# 189     s190    Movie                          Vicky Velingkar
# 263     s264    Movie                     Triple Seat (4K UHD)
# 280     s281    Movie                        Touch Chesi Chudu
# 338     s339    Movie                          Tiger Zinda Hai
# 469     s470  TV Show                                The Remix
# 814     s815  TV Show                                   Tandav
# 872     s873    Movie                    Student of the Year 2
# 936     s937    Movie                   Sonu Ke Titu Ki Sweety
# 937     s938  TV Show  Sons of the Soil : Jaipur Pink Panthers
# ...

# %%
df['rating'].value_counts()
# Out:
# 13+         2117
# 16+         1547
# ALL         1268
# 18+         1243
# R           1010
# PG-13        393
# 7+           385
# PG           253
# NR           223
# TV-14        208
# TV-PG        169
# TV-NR        105
# G             93
# TV-G          81
# TV-MA         77
# TV-Y          74
# TV-Y7         39
# UNRATED       33
# NOT_RATE       3
# AGES_18_       3
# NC-17          3
# AGES_16_       2
# 16             1
# ALL_AGES       1
# Name: rating, dtype: int64

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9668, step=1)

# %%
df.loc[filt,['title','director','description']]
# Out:
#                      title         director  \
# 1     Take Care Good Night     Girish Joshi
# 107                 Whoop!     Kreeti Gogia
# 142    Wedding Cha Shinema  Saleel Kulkarni
# 178               Viswasam             Siva
# 180                  Virus       Aashiq Abu
# ...                    ...              ...
# 7505   The Priest (Telugu)  Jofin T. Chacko
# 8366            Aashiqui 2       Mohit Suri
# 8569    The Priest (Tamil)  Jofin T. Chacko
# 8825        Sunny (4K UHD)   Ranjith Sankar
# 8826                 Sunny   Ranjith Sankar
#
#                                             description
# 1     A Metro Family decides to fight a Cyber Crimin...
# 107   Abish Mathew is the world's greatest stand-up ...
# 142   An aspiring filmmaker reluctantly takes up the...
# 178   A village ruffian, who settles disputes in his...
# 180   Virus is a fiction based on true events, revol...
# ...                                                 ...
# ...

# %%
filt=(df['country']=='India') & (df['type']=='TV Show')
df[filt]
# Out:
#      show_id     type                                    title director  \
# 469     s470  TV Show                                The Remix      NaN
# 814     s815  TV Show                                   Tandav      NaN
# 937     s938  TV Show  Sons of the Soil : Jaipur Pink Panthers      NaN
# 1397   s1398  TV Show                               Paatal Lok      NaN
# 1420   s1421  TV Show                            One Mic Stand      NaN
# 1651   s1652  TV Show                                 Mirzapur      NaN
# 1748   s1749  TV Show                              Man's World      NaN
# 1774   s1775  TV Show                           Made In Heaven      NaN
# 2032   s2033  TV Show                      Jestination Unknown      NaN
# 2102   s2103  TV Show                              Inside Edge      NaN
# 2434   s2435  TV Show                  Four More Shots Please!      NaN
# 2802   s2803  TV Show               Comicstaan Semma Comedy Pa      NaN
# ...

# %%
df['country'].value_counts()
# Out:
# United States                    253
# India                            229
# United Kingdom                    28
# Canada                            16
# United Kingdom, United States     12
#                                 ...
# Poland, United States              1
# France, Belgium                    1
# New Zealand                        1
# Brazil                             1
# United States, Portugal            1
# Name: country, Length: 86, dtype: int64

# %%
countries=['Canada']
filt=df['country'].isin(countries)
df[filt].head(20)
# Out:
#      show_id   type                                        title  \
# 0         s1  Movie                          The Grand Seduction
# 8         s9  Movie                              Global Meltdown
# 10       s11  Movie                               Forest Fairies
# 393     s394  Movie                    The Wild Horse Redemption
# 619     s620  Movie                             The Hollow Child
# 1044   s1045  Movie                               Shadow Company
# 1477   s1478  Movie  No Place to Hide: The Rehtaeh Parsons Story
# 2288   s2289  Movie                                  Griefwalker
# 2709   s2710  Movie                                   Dawn Rider
# 3303   s3304  Movie                                         Amal
# 3584   s3585  Movie                 The Real Inglorious Bastards
# 4002   s4003  Movie                    Out of Mind, Out of Sight
# 4268   s4269  Movie                          The Rape of Nanking
# ...

# %%
filt = df['cast'].str.contains('Ali Fazal', na=False)
df.loc[filt, ['title', 'country', 'rating']]
# Out:
#                    title country rating
# 1651            Mirzapur   India    16+
# 3154  Bang Baaja Baaraat   India    16+
# 3867      Fukrey Returns     NaN    13+
# 5286              Fukrey     NaN     NR

# %%
filt = df['cast'].str.contains('Pankaj Tripathi', na=False)
df.loc[filt, ['title', 'country', 'rating']]
# Out:
#                         title country rating
# 1651                 Mirzapur   India    16+
# 1979           Kaala (Telugu)     NaN    13+
# 1980            Kaala (Tamil)     NaN    13+
# 1981        Kaala (Malayalam)     NaN    13+
# 3250  Angrezi Mein Kehte Hain     NaN     NR
# 3867           Fukrey Returns     NaN    13+
# 5203             Mango Dreams     NaN    13+
# 5262                   Newton     NaN    13+
# 5286                   Fukrey     NaN     NR
# 6157                  Gurgaon     NaN    13+

# %%
filt = df['cast'].str.contains('Siddiqui', na=False)
df.loc[filt, ['title', 'country', 'rating']]
# Out:
#              title               country rating
# 1335    Photograph                   NaN  PG-13
# 2244  Hate Story 4                   NaN    18+
# 5848      New York  India, United States    13+

# %%
df['release_year'].value_counts(normalize=True).head(60)
# Out:
# 2021    0.149152
# 2020    0.099504
# 2019    0.096090
# 2018    0.064439
# 2017    0.058130
# 2016    0.053889
# 2014    0.040443
# 2015    0.039098
# 2013    0.029892
# 2012    0.026065
# 2011    0.026065
# 2010    0.019239
# 2007    0.018204
# 2008    0.017687
# 2009    0.015412
# 2006    0.014274
# 2005    0.011585
# 2004    0.010654
# 2002    0.009516
# 2001    0.008482
# 2000    0.008378
# 2003    0.008378
# 1995    0.007447
# 1999    0.006620
# 1994    0.006516
# 1996    0.006413
# 1998    0.006103
# 1997    0.006103
# 1993    0.005896
# 1992    0.005792
# 1989    0.004655
# 1991    0.004655
# 1988    0.004551
# 1986    0.004137
# 1990    0.004137
# 1987    0.003413
# 1936    0.003000
# 1985    0.002896
# 1984    0.002896
# 1975    0.002793
# 1970    0.002586
# 1980    0.002586
# 1974    0.002482
# 1937    0.002482
# 1978    0.002379
# 1947    0.002276
# 1941    0.002276
# 1981    0.002276
# 1943    0.002172
# 1946    0.002172
# 1950    0.002172
# 1953    0.002172
# ...

# %%
country_grp = df.groupby('country')
country_grp.get_group('United Kingdom')
# Out:
#      show_id     type                              title  \
# 4         s5    Movie                      Monster Maker
# 5         s6    Movie              Living With Dinosaurs
# 14       s15    Movie  Elon Musk: The Real Life Iron Man
# 374     s375    Movie                    The Zombie King
# 656     s657    Movie                           The Flaw
# 821     s822  TV Show         Take Us Home: Leeds United
# 892     s893    Movie                          Stick Man
# 2059   s2060  TV Show        James May: Our Man in Japan
# 2060   s2061  TV Show                 James May: Oh Cook
# 2095   s2096    Movie                      Instant Death
# 2364   s2365    Movie                         Get Duked!
# 2381   s2382    Movie                          Gascoigne
# 2462   s2463  TV Show                            Fleabag
# 2534   s2535    Movie                   Everybody's Game
# 2809   s2810    Movie    Coldplay: A Head Full Of Dreams
# ...

# %%
rating_grp = df.groupby('rating')
rating_grp.get_group('R')
# Out:
#      show_id   type                 title                        director  \
# 19       s20  Movie                   Zoe                   Drake Doremus
# 24       s25  Movie              Zandalee                   Sam Pillsbury
# 36       s37  Movie        You're Not You                 George C. Wolfe
# 59       s60  Movie               Xchange                     Allan Moyle
# 60       s61  Movie                 X-Ray                   Boaz Davidson
# ...      ...    ...                   ...                             ...
# 9643   s9644  Movie    Love & Other Drugs                    Edward Zwick
# 9644   s9645  Movie  Little Miss Sunshine  Jonathan Dayton, Valerie Faris
# 9648   s9649  Movie           Judge Dredd                    Danny Cannon
# 9665   s9666  Movie               Outpost                    Steve Barker
# 9667   s9668  Movie           Harry Brown                   Daniel Barber
#
#                                                    cast        country  \
# ...

# %%
country_grp['type'].value_counts().loc['India']
# Out:
# type
# Movie      213
# TV Show     16
# Name: type, dtype: int64

# %%
filt = df['cast'].str.contains('Rowan Atkinson', na=False)
df[filt]
# Out:
#      show_id     type                          title director  \
# 1582   s1583  TV Show  Mr. Bean: The Animated Series      NaN
# 1583   s1584  TV Show                       Mr. Bean      NaN
#
#                                                cast country date_added  \
# 1582  Rowan Atkinson, Sally Grace, Mathilda Ziegler     NaN        NaN
# 1583                                 Rowan Atkinson     NaN        NaN
#
#       release_year rating  duration        listed_in  \
# 1582          2019     7+  1 Season  Animation, Kids
# 1583          1995     7+  1 Season     Comedy, Kids
#
#                                             description
# 1582  This series follows Mr Bean, his best friend T...
# 1583  Life is a difficult challenge for Mr Bean, who...

# %%
filt = df['listed_in'].str.contains('Anime', na=False)
df.loc[filt].head(60)
# Out:
#      show_id     type                                              title  \
# 21       s22  TV Show                          Zo Zo Zombie: Mini-Series
# 28       s29  TV Show                                    Yu-Gi-Oh! Zexal
# 30       s31  TV Show                                     Yu-Gi-Oh! 5D's
# 139     s140    Movie            Welcome to the Space Show (English Dub)
# 183     s184  TV Show                                       VINLAND SAGA
# 197     s198  TV Show                           Vatican Miracle Examiner
# 211     s212  TV Show                                         UQ Holder!
# 285     s286  TV Show                                          Toradora!
# 549     s550    Movie     The Magic Lamp and the Moving Islands (Subbed)
# 550     s551    Movie     The Magic Lamp and the Moving Islands (Dubbed)
# 558     s559    Movie                              The Little Match Girl
# 792     s793    Movie               Tenkai Knights - Rise of the Knights
# ...
